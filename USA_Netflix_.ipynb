# %% [markdown]
# <a href="https://colab.research.google.com/github/yitai77/Netflix_Data_project/blob/main/USA_Netflix_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# #  [Kaggle] Netflix Data: Cleaning, Analysis and Visualization 데이터

# %%
# 데이터 불러오기
data = pd.read_csv('https://raw.githubusercontent.com/minjung00/Netflix/main/netflix1.csv')

# %% [markdown]
# # Netflix : South Korea and United States 데이터 추출

# %%
# United States, 미국

# 'country' 열이 'United States'인 데이터 추출
usa_data = data[data['country'] == 'United States']
usa_data
# Out:
#      show_id     type                        title  \
# 0         s1    Movie         Dick Johnson Is Dead
# 2         s6  TV Show                Midnight Mass
# 4         s8    Movie                      Sankofa
# 6        s10    Movie                 The Starling
# 13      s471    Movie  Bridgerton - The Afterparty
# ...      ...      ...                          ...
# 8773   s8727  TV Show         When Calls the Heart
# 8777   s8748  TV Show                    Winsanity
# 8779   s8756  TV Show            Women Behind Bars
# 8782   s8781  TV Show                 Yo-Kai Watch
# 8786   s8798  TV Show                    Zak Storm
#
#                              director        country  date_added  \
# 0                     Kirsten Johnson  United States   9/25/2021
# 2                       Mike Flanagan  United States   9/24/2021
# 4                        Haile Gerima  United States   9/24/2021
# 6                      Theodore Melfi  United States   9/24/2021
# ...

# %%
# South Korea, 한국

# 'country' 열이 'South Korea'인 데이터 추출
sk_data = data[data['country'] == 'South Korea']
sk_data
# Out:
#      show_id     type                         title       director  \
# 536     s399    Movie   Kingdom: Ashin of the North  Kim Seong-hun
# 646     s485    Movie  Lee Su-geun: The Sense Coach  Kim Joo-hyung
# 707     s556    Movie                   Snowpiercer   Bong Joon Ho
# 708     s557    Movie                 The 8th Night  Kim Tae-hyung
# 806     s763    Movie                  Sweet & Sour  Lee Kae-byeok
# ...      ...      ...                           ...            ...
# 8705   s8258  TV Show                  The Cravings      Not Given
# 8716   s8331    Movie              The Great Battle      Not Given
# 8726   s8380  TV Show           The Lady in Dignity      Not Given
# 8753   s8576  TV Show               This Is My Love      Not Given
# 8766   s8685  TV Show                       Vroomiz      Not Given
#
#           country date_added  release_year rating   duration  \
# 536   South Korea  7/23/2021          2021  TV-MA     94 min
# ...

# %% [markdown]
# #South Korea and United States의 Movie와 TV show의 개수 비교

# %%
import matplotlib.pyplot as plt


#''type' 열 기준으로 데이터 분류
sk_data_counts = sk_data['type'].value_counts()

#색상 설정
colors = ['violet', 'mistyrose']

#도덧 차트 그리기
plt.pie(sk_data_counts, labels=sk_data_counts.index, autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'white', 'width':0.7}, colors = colors)
plt.axis('equal')
plt.title('Netflix Shows in the South Korea')
plt.show()

# %%
import matplotlib.pyplot as plt
#United States, 미국

#''type' 열 기준으로 데이터 분류
usa_data_counts = usa_data['type'].value_counts()

#색상 설정
colors = ['green', 'mistyrose']

#도덧 차트 그리기
plt.pie(usa_data_counts, labels=usa_data_counts.index, autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'white', 'width':0.7}, colors = colors)
plt.axis('equal')
plt.title('Netflix Shows in the United States')
plt.show()

# %%
# 'type' 열 기준으로 데이터 분류
sk_data_counts = sk_data['type'].value_counts()
usa_data_counts = usa_data['type'].value_counts()
# 그래프 영역 설정
fig, ax = plt.subplots()
# South Korea 그래프 그리기
ax.plot(sk_data_counts.index, sk_data_counts, marker='o', linestyle='-', color='violet', label='South Korea')
# United States 그래프 그리기
ax.plot(usa_data_counts.index, usa_data_counts, marker='o', linestyle='-', color='green', label='United States')
# 축과 제목 설정
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Netflix Shows Comparison')
plt.legend()
# 그래프 출력
plt.show()

# %% [markdown]
# #South Korea and United States의 연도별 작품 수

# %%
# 'year' 열을 기준으로 파이 차트 그리기
# type_counts = sk_data['release_year'].replace(range(1900, 2011), 'before-2010').value_counts()
# plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%')
# plt.title('Netflix Shows in the South Korea')

# 'year' 열을 기준으로 파이 차트 그리기


# 년도 별로 데이터 분류
sk_type_counts = sk_data['release_year'].value_counts().sort_index()


#색깔
color = ['violet']

#선그래프
plt.bar(sk_type_counts.index, sk_type_counts.values, color= color)
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(sk_type_counts.index, sk_type_counts.index.astype(int), rotation=45)
plt.title('Netflix Shows in the South Korea')
plt.show()

# %% [markdown]
# >United States 연도별 작품 수

# %%
# 'year' 열을 기준으로 파이 차트 그리기


# 년도 별로 데이터 분류
type_counts = usa_data['release_year'].value_counts().sort_index()

#색깔
color = ['olive']

#선그래프
plt.bar(type_counts.index, type_counts.values, color= color)
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.title('Netflix Shows in the United States')
plt.show()

# %% [markdown]
# # South Korea and United States의 장르 분포

# %%
# 맨 앞에 있는 값만 추출하여 새로운 열에 저장
data['main_genre'] = data['listed_in'].str.split(',').str[0]
data['main_genre']
# Out:
# 0                  Documentaries
# 1                 Crime TV Shows
# 2                      TV Dramas
# 3       Children & Family Movies
# 4                         Dramas
#                   ...
# 8785      International TV Shows
# 8786                    Kids' TV
# 8787      International TV Shows
# 8788                    Kids' TV
# 8789                    Kids' TV
# Name: main_genre, Length: 8790, dtype: object

# %% [markdown]
# > South Korea 장르

# %%
genre_counts = sk_data['listed_in'].str.split(',').explode().str.strip().value_counts()

# DataFrame 생성
genre_table = pd.DataFrame({'Genre': genre_counts.index, 'Count': genre_counts})

top_10_genres = genre_table.head(10)

# 출력
print(top_10_genres)
# Out:
#                                          Genre  Count
# International TV Shows  International TV Shows    152
# Korean TV Shows                Korean TV Shows    131
# Romantic TV Shows            Romantic TV Shows     76
# International Movies      International Movies     42
# TV Dramas                            TV Dramas     37
# Dramas                                  Dramas     24
# Crime TV Shows                  Crime TV Shows     24
# TV Comedies                        TV Comedies     18
# Action & Adventure          Action & Adventure     16
# Thrillers                            Thrillers     14

# %%
#파이 차트
plt.pie(top_10_genres.Count, labels=top_10_genres.index, autopct='%1.1f%%')

#차트 제목
plt.title('Netflix Shows in the South Korea')

#출력
plt.show()

# %% [markdown]
# >United States 장르

# %%
genre_counts = data['listed_in'].str.split(',').explode().str.strip().value_counts()

# DataFrame 생성
genre_table = pd.DataFrame({'Genre': genre_counts.index, 'Count': genre_counts})

top_10_genres = genre_table.head(10)

# 출력
print(top_10_genres)
# Out:
#                                              Genre  Count
# International Movies          International Movies   2752
# Dramas                                      Dramas   2426
# Comedies                                  Comedies   1674
# International TV Shows      International TV Shows   1349
# Documentaries                        Documentaries    869
# Action & Adventure              Action & Adventure    859
# TV Dramas                                TV Dramas    762
# Independent Movies              Independent Movies    756
# Children & Family Movies  Children & Family Movies    641
# Romantic Movies                    Romantic Movies    616

# %%
#파이 차트
plt.pie(top_10_genres.Count, labels=top_10_genres.index, autopct='%1.1f%%')

#차트 제목
plt.title('Netflix Shows in the United States')

#출력
plt.show()

# %% [markdown]
# # South Korea and United States의 관람등급 분포

# %% [markdown]
# >South Korea 관람등급

# %%
# 관람등급 통계 계산
rating_counts = sk_data['rating'].value_counts().head(10)

# 그래프 설정
plt.figure(figsize=(10, 6))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', colors=['skyblue', 'limegreen', 'orange', 'red', 'purple'])

# 그래프 제목 설정
plt.title('Distribution of Top 10 Ratings for Netflix Content in the South Korea')

# 그래프 출력
plt.show()

# %% [markdown]
# >United States 관람등급

# %%
# 관람등급 통계 계산
rating_counts = usa_data['rating'].value_counts().head(10)

# 그래프 설정
plt.figure(figsize=(10, 6))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', colors=['skyblue', 'limegreen', 'orange', 'red', 'purple'])

# 그래프 제목 설정
plt.title('Distribution of Top 10 Ratings for Netflix Content in the United States')

# 그래프 출력
plt.show()

# %% [markdown]
# # South Korea and United States의 Movie 영상 길이 분포

# %% [markdown]
# > South Korea Movie 영상 길이

# %%
## 한국에서 제작된 영화 데이터 필터링
sk_movies_data = data[(data['country'] == 'South Korea') & (data['type'] == 'Movie')]

# 영상 길이 분포 계산
duration = sk_movies_data['duration'].str.replace(' min', '').astype(int)

# 그래프 설정
plt.figure(figsize=(10, 6))
sns.distplot(duration, bins=30, hist=True, kde=True, color='red')

# 그래프 제목과 축 레이블 설정
plt.title('Distribution of Movie Durations for Netflix Content in the South Korea')
plt.xlabel('Duration (minutes)')
plt.ylabel('Density')

# 그래프 출력
plt.show()
# Out:
# <ipython-input-37-f3b963d34b25>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(duration, bins=30, hist=True, kde=True, color='red')

# %% [markdown]
# >United States Movie 영상 길이

# %%
## 미국에서 제작된 영화 데이터 필터링
usa_movies_data = data[(data['country'] == 'United States') & (data['type'] == 'Movie')]

# 영상 길이 분포 계산
duration = usa_movies_data['duration'].str.replace(' min', '').astype(int)

# 그래프 설정
plt.figure(figsize=(10, 6))
sns.distplot(duration, bins=30, hist=True, kde=True, color='green')

# 그래프 제목과 축 레이블 설정
plt.title('Distribution of Movie Durations for Netflix Content in the United States')
plt.xlabel('Duration (minutes)')
plt.ylabel('Density')

# 그래프 출력
plt.show()
# Out:
# <ipython-input-39-367b692d9e84>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(duration, bins=30, hist=True, kde=True, color='green')

# %% [markdown]
# # South Korea and United States의 TV show 시즌 개수 분포

# %% [markdown]
# >South Korea TV show 시즌 개수

# %%
# 한국에서 제작된 TV 쇼 데이터 필터링
sk_tv_shows_data = data[(data['country'] == 'South Korea') & (data['type'] == 'TV Show')]

# 영상 길이 분포 계산
seasons = sk_tv_shows_data['duration'].str.extract('(\d+)').astype(int)

# 그래프 설정
plt.figure(figsize=(10, 6))
sns.distplot(seasons, bins=30, hist=True, kde=True, color='red')

# 그래프 제목과 축 레이블 설정
plt.title('Distribution of TV Show Durations (Seasons) for Netflix Content in the South Korea')
plt.xlabel('Number of Seasons')
plt.ylabel('Count')

# 그래프 출력
plt.show()
# Out:
# <ipython-input-40-8b58ec86567d>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(seasons, bins=30, hist=True, kde=True, color='red')

# %% [markdown]
# >United StatesTV show 시즌 개수

# %%
# 미국에서 제작된 TV 쇼 데이터 필터링
usa_tv_shows_data = data[(data['country'] == 'United States') & (data['type'] == 'TV Show')]

# 영상 길이 분포 계산
seasons = usa_tv_shows_data['duration'].str.extract('(\d+)').astype(int)

# 그래프 설정
plt.figure(figsize=(10, 6))
sns.distplot(seasons, bins=30, hist=True, kde=True, color='green')

# 그래프 제목과 축 레이블 설정
plt.title('Distribution of TV Show Durations (Seasons) for Netflix Content in the United States')
plt.xlabel('Number of Seasons')
plt.ylabel('Density')

# 그래프 출력
plt.show()
# Out:
# <ipython-input-41-545d269bae1c>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(seasons, bins=30, hist=True, kde=True, color='green')
